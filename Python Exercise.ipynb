# %%
Num1 = int (input ("enter Num1 : "))
Num2 = int(input ("enter Num2 : "))
Add = Num1 + Num2
print("Add : " ,Add)
# Out:
# enter Num1 :  10
# enter Num2 :  30
# Add :  40

# %%
#BMI Calculator with Category Classification

# %%
weight = float (input("Enter weight in Kg : "))
Height = float (input("Enter Height in Cm : "))
#convert cm to m
Height_in_m = Height /100
#calculate BMI
BMI = weight / Height_in_m
#Display calculations
print(" Your Weight in Kg is : ",weight)
print("Your Height in meters is : ", Height_in_m)
print("Your BMI is : ", BMI)
#Classifying the category
if BMI < 18.5:
    print("Status: Underweight")
elif BMI < 25:
    print("Status: Healthy weight")
elif BMI < 30:
    print("Status: Overweight")
else:
    print("Status: Obese")
# Out:
# Enter weight in Kg :  80
# Enter Height in Cm :  164
#  Your Weight in Kg is :  80.0
# Your Height in meters is :  1.64
# Your BMI is :  48.78048780487805
# Status: Obese
